# %% [markdown]
# # Fuel Visualisation Assigment

# %%
import pandas as pd

# %%
df = pd.read_csv('fuel.csv')

# %%
df
# Out:
#          id        make             model  year           VClass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fuelType  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
df.columns.str.lower()
# Out:
# Index(['id', 'make', 'model', 'year', 'vclass', 'drive', 'trans', 'fueltype',
#        'cylinders', 'displacement', 'combined fuel efficiency',
#        'co2 emission'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
df[['transmission_type', 'code']] = df.trans.str.split(' ',n=1, expand=True)

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %% [markdown]
# ### cleaning the transmission type column to get only 'Automatic' and 'manual'

# %%
df.rename(columns = {'combined fuel efficiency':'combined_fuel_efficiency'}, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'make', 'model', 'year', 'vclass', 'drive', 'trans', 'fueltype',
#        'cylinders', 'displacement', 'combined_fuel_efficiency', 'co2 emission',
#        'transmission_type', 'code'],
#       dtype='object')

# %%
df.head(3)
# Out:
#       id        make model  year           vclass              drive  \
# 0  32204      Nissan  GT-R  2013  Subcompact Cars    All-Wheel Drive
# 1  32205  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
# 2  32206  Volkswagen    CC  2013     Compact Cars  Front-Wheel Drive
#
#                trans          fueltype  cylinders  displacement  \
# 0    Automatic (AM6)  Premium Gasoline          6           3.8
# 1  Automatic (AM-S6)  Premium Gasoline          4           2.0
# 2     Automatic (S6)  Premium Gasoline          6           3.6
#
#    combined_fuel_efficiency  co2 emission transmission_type     code
# 0                   18.7389           471         Automatic    (AM6)
# 1                   25.2227           349         Automatic  (AM-S6)
# 2                   20.6716           429         Automatic     (S6)

# %% [markdown]
# id - Categorical
# make - Categorical
# model - Categorical
# vclass - categorical
# drive - categorical
# fueltype - categorical
# cylinders _ categorical
# displacement - quantitative
# combined fuel effieciency- quatitative
# co2 emission - quatitative
# transmission type - Categorical

# %% [markdown]
# # Categorical Univariative Visual

# %%
df.vclass.value_counts()
# Out:
# Midsize Cars        1188
# Compact Cars        1122
# Subcompact Cars      673
# Large Cars           625
# Minicompact Cars     321
# Name: vclass, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.countplot(data=df,x='vclass', color= 'Orange')
plt.title('Vclass by Fuel Type');

# %%
df.transmission_type.value_counts()
# Out:
# Automatic    3068
# Manual        861
# Name: transmission_type, dtype: int64

# %%
df.transmission_type.value_counts().index
# Out:
# Index(['Automatic', 'Manual'], dtype='object')

# %%
a = df.transmission_type.value_counts()
x = df.transmission_type.value_counts().index
y = df.transmission_type.value_counts().values
plt.pie(x=a, labels = x)
plt.title('Transmission Frequency');

# %% [markdown]
# # Quantitative Univariative Visual

# %%
df.combined_fuel_efficiency.value_counts()
# Out:
# 21.4055    26
# 22.7798    24
# 17.6782    18
# 32.0000    16
# 18.2395    15
#            ..
# 23.7209     1
# 35.4320     1
# 28.5566     1
# 34.0347     1
# 21.3945     1
# Name: combined_fuel_efficiency, Length: 2110, dtype: int64

# %%
plt.hist(data=df,x = 'combined_fuel_efficiency', color = 'Orange')
plt.xlabel('combined_fuel_efficiency')
plt.ylabel('frequency')
plt.title('Combined Fuel Efficiency');

# %% [markdown]
# # Bivariate Visuals
# ### Two Categorical Variables

# %%
import numpy as np

# %%
np.mean(df.cylinders)
# Out:
# 5.468312547722067

# %%
df['size'] = np.where(df.cylinders > np.mean(df.cylinders), 'large', 'small')

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
sns.countplot(data=df, x='year', hue= 'size')
plt.xlabel('year')
plt.ylabel('size')
plt.title('Size of Cylinders by Year');

# %% [markdown]
# ### Two Quantitative Variables

# %%
plt.scatter(data=df, x = 'displacement', y = 'co2 emission')
plt.xlabel('displacement')
plt.ylabel('co2 emission')
plt.title('Displacement by CO2 Emission');

# %%
df
# Out:
#          id        make             model  year           vclass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fueltype  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %% [markdown]
# ### Categorical and Quantitative visual

# %%
plt.figure(figsize=[20,5])

plt.subplot(1,2,1)
sns.violinplot(data=df, x = 'year', y='displacement')
plt.xlabel('year')
plt.ylabel('displacement')
plt.title('Displacement by Year');

plt.subplot(1,2,2)
sns.boxplot(data=df, x = 'year', y='displacement')
plt.xlabel('year')
plt.ylabel('displacement')
plt.title('Displacement by Year');
